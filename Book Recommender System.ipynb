# %%
import numpy as np
import pandas as pd

# %%
books= pd.read_csv('books.csv',sep=";",error_bad_lines=False,encoding='latin-1')
# Out:
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# b'Skipping line 209388: expected 8 fields, saw 9\nSkipping line 220626: expected 8 fields, saw 9\nSkipping line 227933: expected 8 fields, saw 11\nSkipping line 228957: expected 8 fields, saw 10\nSkipping line 245933: expected 8 fields, saw 9\nSkipping line 251296: expected 8 fields, saw 9\nSkipping line 259941: expected 8 fields, saw 9\nSkipping line 261529: expected 8 fields, saw 9\n'
# C:\Users\Nishith\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books=books[['ISBN','Book-Title','Book-Author','Year-Of-Publication','Publisher']]

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company

# %%
books=books.rename(columns={'Book-Title':'title','Book-Author':'author','Year-Of-Publication':'year','Publisher':'publisher'})

# %%
books.head(1)
# Out:
#          ISBN                title              author  year  \
# 0  0195153448  Classical Mythology  Mark P. O. Morford  2002
#
#                  publisher
# 0  Oxford University Press

# %%
users= pd.read_csv('users.csv',sep=";",error_bad_lines=False,encoding='latin-1')

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users=users.rename(columns={'User-ID':'user_id','Location':'location','Age':'age'})

# %%
users.head()
# Out:
#    user_id                            location   age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings= pd.read_csv('ratings.csv',sep=";",error_bad_lines=False,encoding='latin-1')

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings=ratings.rename(columns={'User-ID':'user_id','Book-Rating':'rating'})

# %%
ratings.head()
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
books.shape
# Out:
# (271360, 5)

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
ratings['user_id'].value_counts()
# Out:
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 271728        1
# 245123        1
# 234886        1
# 259466        1
# 187812        1
# Name: user_id, Length: 105283, dtype: int64

# %%
ratings['user_id'].value_counts().shape
# Out:
# (105283,)

# %%
x=ratings['user_id'].value_counts()>150

# %%
x[x]
# Out:
# 11676     True
# 198711    True
# 153662    True
# 98391     True
# 35859     True
#           ...
# 83109     True
# 264525    True
# 138995    True
# 41781     True
# 149690    True
# Name: user_id, Length: 1223, dtype: bool

# %%
x[x].shape
# Out:
# (1223,)

# %%
y=x[x].index

# %%
y
# Out:
# Int64Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352,
#             110973, 235105,
#             ...
#             132663, 185771, 233711, 267033,  14638,  83109, 264525, 138995,
#              41781, 149690],
#            dtype='int64', length=1223)

# %%
ratings=ratings[ratings['user_id'].isin(y)]

# %%
ratings.shape
# Out:
# (582644, 3)

# %%
ratings.head()
# Out:
#       user_id        ISBN  rating
# 1456   277427  002542730X      10
# 1457   277427  0026217457       0
# 1458   277427  003008685X       8
# 1459   277427  0030615321       0
# 1460   277427  0060002050       0

# %%
ratings_with_books=ratings.merge(books,on='ISBN')

# %%
ratings_with_books
# Out:
#         user_id        ISBN  rating  \
# 0        277427  002542730X      10
# 1          3363  002542730X       0
# 2         11676  002542730X       6
# 3         12538  002542730X      10
# 4         13552  002542730X       0
# ...         ...         ...     ...
# 539222   276680  089587167X       7
# 539223   276680  1402201435       4
# 539224   276680  1564407284       0
# 539225   276680  1582343594       0
# 539226   276680  1888173408       7
#
#                                                     title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1       Politically Correct Bedtime Stories: Modern Ta...
# 2       Politically Correct Bedtime Stories: Modern Ta...
# 3       Politically Correct Bedtime Stories: Modern Ta...
# 4       Politically Correct Bedtime Stories: Modern Ta...
# ...                                                   ...
# 539222                                     Something Blue
# 539223                                 The One True Ocean
# 539224  The Old Sturbridge Village Cookbook, 2nd : Aut...
# 539225                 City of Masks : A Cree Black Novel
# 539226                Fairy Tale (Common Reader Editions)
#
#                          author  year                  publisher
# 0             James Finn Garner  1994  John Wiley &amp; Sons Inc
# 1             James Finn Garner  1994  John Wiley &amp; Sons Inc
# 2             James Finn Garner  1994  John Wiley &amp; Sons Inc
# 3             James Finn Garner  1994  John Wiley &amp; Sons Inc
# 4             James Finn Garner  1994  John Wiley &amp; Sons Inc
# ...                         ...   ...                        ...
# 539222  Jean Christopher Spaugh  1997    John F. Blair Publisher
# 539223        Sarah Beth Martin  2003       Sourcebooks Landmark
# 539224           Caroline Sloat  1995               Globe Pequot
# 539225             Daniel Hecht  2004             Bloomsbury USA
# 539226       Alice Thomas Ellis  2001              Akadine Press
#
# [539227 rows x 7 columns]

# %%
ratings_with_books.shape
# Out:
# (539227, 7)

# %%
ratings_with_books.groupby('title')['rating'].count().reset_index()
# Out:
#                                                     title  rating
# 0        A Light in the Storm: The Civil War Diary of ...       3
# 1                                   Always Have Popsicles       1
# 2                    Apple Magic (The Collector's series)       1
# 3        Beyond IBM: Leadership Marketing and Finance ...       1
# 4        Clifford Visita El Hospital (Clifford El Gran...       1
# ...                                                   ...     ...
# 170106  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...       3
# 170107                                      Ã?Â?lpiraten.       1
# 170108                     Ã?Â?rger mit Produkt X. Roman.       2
# 170109                              Ã?Â?stlich der Berge.       1
# 170110                                  Ã?Â?thique en toc       1
#
# [170111 rows x 2 columns]

# %%
number_rating=ratings_with_books.groupby('title')['rating'].count().reset_index().rename(columns={'rating':'number of rating'})

# %%
number_rating
# Out:
#                                                     title  number of rating
# 0        A Light in the Storm: The Civil War Diary of ...                 3
# 1                                   Always Have Popsicles                 1
# 2                    Apple Magic (The Collector's series)                 1
# 3        Beyond IBM: Leadership Marketing and Finance ...                 1
# 4        Clifford Visita El Hospital (Clifford El Gran...                 1
# ...                                                   ...               ...
# 170106  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...                 3
# 170107                                      Ã?Â?lpiraten.                 1
# 170108                     Ã?Â?rger mit Produkt X. Roman.                 2
# 170109                              Ã?Â?stlich der Berge.                 1
# 170110                                  Ã?Â?thique en toc                 1
#
# [170111 rows x 2 columns]

# %%
final_rating=ratings_with_books.merge(number_rating,on='title')

# %%
final_rating
# Out:
#         user_id        ISBN  rating  \
# 0        277427  002542730X      10
# 1          3363  002542730X       0
# 2         11676  002542730X       6
# 3         12538  002542730X      10
# 4         13552  002542730X       0
# ...         ...         ...     ...
# 539222   276680  089587167X       7
# 539223   276680  1402201435       4
# 539224   276680  1564407284       0
# 539225   276680  1582343594       0
# 539226   276680  1888173408       7
#
#                                                     title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1       Politically Correct Bedtime Stories: Modern Ta...
# 2       Politically Correct Bedtime Stories: Modern Ta...
# 3       Politically Correct Bedtime Stories: Modern Ta...
# 4       Politically Correct Bedtime Stories: Modern Ta...
# ...                                                   ...
# 539222                                     Something Blue
# 539223                                 The One True Ocean
# 539224  The Old Sturbridge Village Cookbook, 2nd : Aut...
# 539225                 City of Masks : A Cree Black Novel
# 539226                Fairy Tale (Common Reader Editions)
#
#                          author  year                  publisher  \
# 0             James Finn Garner  1994  John Wiley &amp; Sons Inc
# 1             James Finn Garner  1994  John Wiley &amp; Sons Inc
# 2             James Finn Garner  1994  John Wiley &amp; Sons Inc
# 3             James Finn Garner  1994  John Wiley &amp; Sons Inc
# 4             James Finn Garner  1994  John Wiley &amp; Sons Inc
# ...                         ...   ...                        ...
# 539222  Jean Christopher Spaugh  1997    John F. Blair Publisher
# 539223        Sarah Beth Martin  2003       Sourcebooks Landmark
# 539224           Caroline Sloat  1995               Globe Pequot
# 539225             Daniel Hecht  2004             Bloomsbury USA
# 539226       Alice Thomas Ellis  2001              Akadine Press
#
#         number of rating
# 0                     88
# 1                     88
# 2                     88
# 3                     88
# 4                     88
# ...                  ...
# 539222                 1
# 539223                 1
# 539224                 1
# 539225                 1
# 539226                 1
#
# [539227 rows x 8 columns]

# %%
final_rating.shape
# Out:
# (539227, 8)

# %%
final_rating['number of rating']>=30
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 539222    False
# 539223    False
# 539224    False
# 539225    False
# 539226    False
# Name: number of rating, Length: 539227, dtype: bool

# %%
final_rating=final_rating[final_rating['number of rating']>=30]

# %%
final_rating.shape
# Out:
# (121097, 8)

# %%
final_rating.drop_duplicates(['user_id','title'])
# Out:
#         user_id        ISBN  rating  \
# 0        277427  002542730X      10
# 1          3363  002542730X       0
# 2         11676  002542730X       6
# 3         12538  002542730X      10
# 4         13552  002542730X       0
# ...         ...         ...     ...
# 377385    68185  0393324826       7
# 377386    78783  0393324826      10
# 377387   126604  0393324826       0
# 377388   156150  0393324826       0
# 377389   204864  0393324826       0
#
#                                                     title             author  \
# 0       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 1       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 2       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 3       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 4       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# ...                                                   ...                ...
# 377385         Stiff: The Curious Lives of Human Cadavers         Mary Roach
# 377386         Stiff: The Curious Lives of Human Cadavers         Mary Roach
# 377387         Stiff: The Curious Lives of Human Cadavers         Mary Roach
# 377388         Stiff: The Curious Lives of Human Cadavers         Mary Roach
# 377389         Stiff: The Curious Lives of Human Cadavers         Mary Roach
#
#         year                   publisher  number of rating
# 0       1994   John Wiley &amp; Sons Inc                88
# 1       1994   John Wiley &amp; Sons Inc                88
# 2       1994   John Wiley &amp; Sons Inc                88
# 3       1994   John Wiley &amp; Sons Inc                88
# 4       1994   John Wiley &amp; Sons Inc                88
# ...      ...                         ...               ...
# 377385  2004  W. W. Norton &amp; Company                41
# 377386  2004  W. W. Norton &amp; Company                41
# 377387  2004  W. W. Norton &amp; Company                41
# 377388  2004  W. W. Norton &amp; Company                41
# 377389  2004  W. W. Norton &amp; Company                41
#
# [118174 rows x 8 columns]

# %%
final_rating=final_rating.drop_duplicates(['user_id','title'])

# %%
final_rating.shape
# Out:
# (118174, 8)

# %%
book_pivot=final_rating.pivot_table(columns='user_id',index='title',values='rating')

# %%
book_pivot
# Out:
# user_id                                             254     1733    1903    \
# title
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 16 Lighthouse Road                                     NaN     NaN     NaN
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# ...                                                    ...     ...     ...
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zlata's Diary: A Child's Life in Sarajevo              NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             2033    2110    2276    \
# title
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 16 Lighthouse Road                                     NaN     NaN     NaN
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     0.0
# ...                                                    ...     ...     ...
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zlata's Diary: A Child's Life in Sarajevo              NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    0.0     NaN     NaN
#
# user_id                                             2766    2891    2977    \
# title
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 16 Lighthouse Road                                     NaN     NaN     NaN
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# ...                                                    ...     ...     ...
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zlata's Diary: A Child's Life in Sarajevo              NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             3363    ...  274308  \
# title                                                       ...
# 10 Lb. Penalty                                         NaN  ...     0.0
# 16 Lighthouse Road                                     NaN  ...     NaN
# 1984                                                   NaN  ...     NaN
# 1st to Die: A Novel                                    NaN  ...     NaN
# 2010: Odyssey Two                                      NaN  ...     NaN
# ...                                                    ...  ...     ...
# You Belong To Me                                       NaN  ...     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     NaN
# Zlata's Diary: A Child's Life in Sarajevo              0.0  ...     NaN
# Zoya                                                   NaN  ...     NaN
# \O\" Is for Outlaw"                                    NaN  ...     NaN
#
# user_id                                             274808  275970  276018  \
# title
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 16 Lighthouse Road                                     NaN     NaN     NaN
# 1984                                                   NaN     0.0     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# ...                                                    ...     ...     ...
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zlata's Diary: A Child's Life in Sarajevo              NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             276680  277427  277478  \
# title
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 16 Lighthouse Road                                     NaN     NaN     NaN
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# ...                                                    ...     ...     ...
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zlata's Diary: A Child's Life in Sarajevo              NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             277639  278188  278418
# title
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 16 Lighthouse Road                                     NaN     0.0     NaN
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# ...                                                    ...     ...     ...
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zlata's Diary: A Child's Life in Sarajevo              NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# [2039 rows x 1213 columns]

# %%
book_pivot=book_pivot.fillna(0)

# %%
book_pivot
# Out:
# user_id                                             254     1733    1903    \
# title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zlata's Diary: A Child's Life in Sarajevo              0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             2033    2110    2276    \
# title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zlata's Diary: A Child's Life in Sarajevo              0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             2766    2891    2977    \
# title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zlata's Diary: A Child's Life in Sarajevo              0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             3363    ...  274308  \
# title                                                       ...
# 10 Lb. Penalty                                         0.0  ...     0.0
# 16 Lighthouse Road                                     0.0  ...     0.0
# 1984                                                   0.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2010: Odyssey Two                                      0.0  ...     0.0
# ...                                                    ...  ...     ...
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zlata's Diary: A Child's Life in Sarajevo              0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# user_id                                             274808  275970  276018  \
# title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zlata's Diary: A Child's Life in Sarajevo              0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             276680  277427  277478  \
# title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zlata's Diary: A Child's Life in Sarajevo              0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             277639  278188  278418
# title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zlata's Diary: A Child's Life in Sarajevo              0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [2039 rows x 1213 columns]

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse=csr_matrix(book_pivot)

# %%
type(book_sparse)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model=NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distances,suggestions=model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1),n_neighbors=6)

# %%
distances
# Out:
# array([[ 0.        , 26.11512971, 27.        , 27.03701167, 27.07397274,
#         27.09243437]])

# %%
suggestions
# Out:
# array([[ 237, 2010,  489,  973,   99, 1365]], dtype=int64)

# %%
for i in range(len(suggestions)):
    print(book_pivot.index[suggestions[i]])
# Out:
# Index(['Blue Moon', 'Wild Justice', 'Engaging Men (Red Dress Ink (Paperback))',
#        'Narcissus in Chains (Anita Blake Vampire Hunter (Paperback))',
#        'After the Fire', 'Tapestry'],
#       dtype='object', name='title')

# %%
np.where(book_pivot.index=='Animal Farm')[0][0]
# Out:
# 141

# %%
def recommend_book(book_name):
    book_id=np.where(book_pivot.index=='Animal Farm')[0][0]
    distances,suggestions=model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1),n_neighbors=6)
    
    for i in range(len(suggestions)):
        if i==0:
            print("The suggestions for the book '", book_name,"' are :")
        if not i:
            print(book_pivot.index[suggestions[i]])

# %%
recommend_book('Blue Moon')
# Out:
# The suggestions for the book ' Blue Moon ' are :
# Index(['Animal Farm', 'Women in His Life',
#        'Blood and Gold (Rice, Anne, Vampire Chronicles.)', 'Billy',
#        'Unnatural Causes', 'Poland'],
#       dtype='object', name='title')
